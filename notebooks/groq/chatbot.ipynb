# %%
from dotenv import load_dotenv

load_dotenv()

#add groq option
from groq import Groq

groq_client = Groq()
groq_model = "qwen/qwen3.8-27b"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)
    
def chat(messages):
    message = groq_client.chat.completions.create(
        model=groq_model,
        max_tokens=1000,
        messages=messages
    )
    return message.choices[0].message.content

# %%
#Make an intial message list
messages = []

# Use a while loop to keep the conversation going until the user types "exit"
while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("Exiting the chat. Goodbye!")
        break
    add_user_message(messages, user_input)
    response = chat(messages)
    add_assistant_message(messages, response)
    print(f"Assistant: {response}")
# Out:
# Assistant: 1 plus 1 is **2**.
# Assistant: It looks like there might be a typo in your question ("wht is 2 plus answers").
#
# If you meant **"What is 2 plus 2?"**, the answer is **4**.
#
# If you meant **"What is 2 plus [some number]?"**, please let me know what number you meant!
# Exiting the chat. Goodbye!
