# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#add groq option
from groq import Groq

groq_client = Groq()
groq_model = "qwen/qwen3.8-27b"

# %%
message = groq_client.chat.completions.create(
    model=groq_model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Write a poem about the beauty of nature."
        }
    ]
)

# %%
from IPython.display import display, Markdown

display(Markdown(message.choices[0].message.content))
# Out:
# **The Green Cathedral**
#
# The morning light filters through the veil,
# Of mist that curls beneath the oak tree’s bough,
# Where dew-kissed leaves whisper secrets revealed,
# In shades of emerald, deep and bright.
#
# The river hums a low, clear tune,
# Over stones worn smooth by ancient years,
# Reflecting glimpses of the moon,
# Or sunbeams dancing, sudden, clear.
#
# Above, the sky stretches, wide and blue,
# A canvas stitched with clouds of cotton white,
# Where silent birds trace arcs, into the view,
# Creating patterns in the pure, bright light.
#
# The forest breathes with life unseen,
# Where roots entwine in dark, rich soil,
# A world of rustling, green, and green,
# Peaceful, profound, for morning’s toil.
#
# No human footfall needs to tread,
# To find the grace within the wild,
# For nature offers, overhead,
# Its timeless, quiet, restful child.
#
# In every petal, blade, and stream,
# A masterpiece of earth and air,
# A symphony of living dream,
# Beyond the noise, beyond despair.
#
# So stand still, let the wind pass by,
# And watch the world begin to wake,
# Under the vast and open sky,
# For nature’s beauty, for sake’s sake.

# %%
message = groq_client.chat.completions.create(
    model=groq_model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Write another sentence."
        }
    ]
)

# %%
display(Markdown(message.choices[0].message.content))
# Out:
# The wind rustled through the leafless branches, whispering secrets against the cold November air.

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)
    
def chat(messages):
    message = groq_client.chat.completions.create(
        model=groq_model,
        max_tokens=1000,
        messages=messages
    )
    return message.choices[0].message.content

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Write a poem about the beauty of nature.")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence.")

# Get the follow-up response with full context
final_answer = chat(messages)

display(Markdown(final_answer))
# Out:
# The sun casts long, golden shadows across the meadow, turning the swaying grass into a shimmering sea of amber light.
