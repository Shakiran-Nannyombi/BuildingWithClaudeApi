# %% [markdown]
# Load Variables

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Create an API client 
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Write a poem about the beauty of nature."
        }
    ]
)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 message = client.messages.create(
#       2     model=model,
#       3     max_tokens=1000,
#       4     messages=[
#
# File ~/Desktop/Projects/BuildingWithClaudeApi/.venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Desktop/Projects/BuildingWithClaudeApi/.venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:978, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, thinking, tool_choice, tools, user_profile_id, workspace_id, extra_headers, extra_query, extra_body, timeout)
#     963     warnings.warn(
#     964         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     965         UserWarning,
#     966         stacklevel=3,
#     967     )
#     969 extra_headers = {
#     970     **strip_not_given(
#     971         {
#    (...)    976     **(extra_headers or {}),
#     977 }
# --> 978 return self._post(
#     979     "/v1/messages",
#     980     body=maybe_transform(
#     981         {
#     982             "max_tokens": max_tokens,
#     983             "messages": messages,
#     984             "model": model,
#     985             "cache_control": cache_control,
#     986             "container": container,
#     987             "inference_geo": inference_geo,
#     988             "metadata": metadata,
#     989             "output_config": output_config,
#     990             "service_tier": service_tier,
#     991             "stop_sequences": stop_sequences,
#     992             "stream": stream,
#     993             "system": system,
#     994             "thinking": thinking,
#     995             "tool_choice": tool_choice,
#     996             "tools": tools,
#     997         },
#     998         message_create_params.MessageCreateParamsStreaming
#     999         if stream
#    1000         else message_create_params.MessageCreateParamsNonStreaming,
#    1001     ),
#    1002     options=make_request_options(
#    1003         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1004     ),
#    1005     cast_to=Message,
#    1006     stream=stream or False,
#    1007     stream_cls=Stream[RawMessageStreamEvent],
#    1008 )
#
# File ~/Desktop/Projects/BuildingWithClaudeApi/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1511, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1507     raise TypeError("Passing both `files` and `content` is not supported")
#    1508 opts = FinalRequestOptions.construct(
#    1509     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1510 )
# -> 1511 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/Projects/BuildingWithClaudeApi/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CfAb2KthAw9j6cReuVJ99'}

# %%
message.content[0].text

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Write another sentence."
        }
    ]
)

# %%
message.content[0].text

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)
    
def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Write a poem about the beauty of nature.")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence.")

# Get the follow-up response with full context
final_answer = chat(messages)
final_answer
